# %% [markdown]
# # EDA SESSION LUMEN

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('mobile sales.csv')

# %%
df
# Out:
#       brand           model base_color processor screen_size  ROM  RAM  \
# 0     Apple       iPhone SE      Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE        Red     Water  Very Small   64    2
# 3     Apple       iPhone XR     Others       iOS      Medium   64    3
# 4     Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..      ...             ...        ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# ...

# %%
df.describe()
# Out:
#               ROM         RAM  display_size  num_rear_camera  \
# count  430.000000  430.000000    430.000000       430.000000
# mean   105.748837    5.320930      6.369767         2.904651
# std     63.164064    2.182635      0.369549         0.952350
# min      8.000000    1.000000      4.700000         1.000000
# 25%     64.000000    4.000000      6.300000         2.000000
# 50%    128.000000    4.000000      6.500000         3.000000
# 75%    128.000000    6.000000      6.500000         4.000000
# max    512.000000   12.000000      7.600000         4.000000
#
#        num_front_camera  battery_capacity     ratings  num_of_ratings  \
# count        430.000000        430.000000  430.000000      430.000000
# mean           1.044186       4529.397674    4.339302    23567.944186
# std            0.227280        986.907252    0.151494    56096.277784
# min            1.000000       1800.000000    3.000000        4.000000
# ...

# %%
df.groupby(['brand']).count()
# Out:
#          model  base_color  processor  screen_size  ROM  RAM  display_size  \
# brand
# Apple       56          56         56           56   56   56            56
# Poco        56          56         56           56   56   56            56
# Realme     138         138        138          138  138  138           138
# Samsung    119         119        119          119  119  119           119
# Xiaomi      61          61         61           61   61   61            61
#
#          num_rear_camera  num_front_camera  battery_capacity  ratings  \
# brand
# Apple                 56                56                56       56
# Poco                  56                56                56       56
# Realme               138               138               138      138
# Samsung              119               119               119      119
# Xiaomi                61                61                61       61
#
#          num_of_ratings  sales_price  discount_percent  sales
# brand
# ...

# %%
df.shape
# Out:
# (430, 16)

# %%
df['sales_price'].max()
# Out:
# 157999

# %%
df.query('sales_price>157990')
# Out:
#        brand              model base_color processor screen_size  ROM  RAM  \
# 309  Samsung  Galaxy Z Fold3 5G      Black  Qualcomm  Very Large  512   12
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# 309           7.6                3                 1              4400
#
#      ratings  num_of_ratings  sales_price  discount_percent  sales
# 309      4.4               7       157999              0.12   0.11

# %%
df.isnull().sum()
# Out:
# brand               0
# model               0
# base_color          0
# processor           0
# screen_size         0
# ROM                 0
# RAM                 0
# display_size        0
# num_rear_camera     0
# num_front_camera    0
# battery_capacity    0
# ratings             0
# num_of_ratings      0
# sales_price         0
# discount_percent    0
# sales               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df['sales_price'].plot(kind='bar', title='SALES')
# Out:
# <AxesSubplot:title={'center':'SALES'}>

# %%
df.reset_index()
# Out:
#      index   brand           model base_color processor screen_size  ROM  RAM  \
# 0        0   Apple       iPhone SE      Black     Water  Very Small   64    2
# 1        1   Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2        2   Apple       iPhone SE        Red     Water  Very Small   64    2
# 3        3   Apple       iPhone XR     Others       iOS      Medium   64    3
# 4        4   Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..     ...     ...             ...        ...       ...         ...  ...  ...
# 425    425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426    426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427    427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428    428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429    429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
# ...

# %%
df1 = df.groupby('brand').mean()
df1 = df1.reset_index()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             5 non-null      object
#  1   ROM               5 non-null      float64
#  2   RAM               5 non-null      float64
#  3   display_size      5 non-null      float64
#  4   num_rear_camera   5 non-null      float64
#  5   num_front_camera  5 non-null      float64
#  6   battery_capacity  5 non-null      float64
#  7   ratings           5 non-null      float64
#  8   num_of_ratings    5 non-null      float64
#  9   sales_price       5 non-null      float64
#  10  discount_percent  5 non-null      float64
#  11  sales             5 non-null      float64
# dtypes: float64(11), object(1)
# memory usage: 608.0+ bytes

# %%
df1
# Out:
#      brand         ROM       RAM  display_size  num_rear_camera  \
# 0    Apple  127.428571  3.500000      5.789286         1.607143
# 1     Poco  104.571429  5.732143      6.589286         3.464286
# 2   Realme  103.188406  5.688406      6.444203         3.166667
# 3  Samsung  110.117647  5.739496      6.490756         3.201681
# 4   Xiaomi   84.196721  4.967213      6.296721         2.409836
#
#    num_front_camera  battery_capacity   ratings  num_of_ratings   sales_price  \
# 0          1.000000       2765.196429  4.562500     4822.964286  57748.107143
# 1          1.017857       5247.321429  4.325000    32285.410714  15936.500000
# 2          1.065217       4797.318841  4.343478    29227.181159  17105.521739
# 3          1.033613       4846.218487  4.242017     6984.798319  28823.537815
# 4          1.081967       4265.737705  4.327869    52321.393443  16711.311475
#
#    discount_percent      sales
# 0          0.064286  19.486964
# 1          0.162143  43.523571
# ...

# %%
df1.plot(x='brand',y='sales_price',kind='bar')
# Out:
# <AxesSubplot:xlabel='brand'>

# %%
df1.plot(x='brand',y='battery_capacity',title='AVG BATTERY CAPACITY',kind='bar')
# Out:
# <AxesSubplot:title={'center':'AVG BATTERY CAPACITY'}, xlabel='brand'>

# %%
df1.plot(x='brand',y='ratings',title='AVG RATINGS',kind='bar')
# Out:
# <AxesSubplot:title={'center':'AVG RATINGS'}, xlabel='brand'>

# %%
df1.plot(x='brand',y='RAM',title='AVG RAM',kind='bar')
# Out:
# <AxesSubplot:title={'center':'AVG RAM'}, xlabel='brand'>

# %%
df2 = df.groupby('processor').count()

# %%
df2
# Out:
#            brand  model  base_color  screen_size  ROM  RAM  display_size  \
# processor
# Ceramic       33     33          33           33   33   33            33
# Exynos        53     53          53           53   53   53            53
# MediaTek     144    144         144          144  144  144           144
# Others         9      9           9            9    9    9             9
# Qualcomm     168    168         168          168  168  168           168
# Water         11     11          11           11   11   11            11
# iOS           12     12          12           12   12   12            12
#
#            num_rear_camera  num_front_camera  battery_capacity  ratings  \
# processor
# Ceramic                 33                33                33       33
# Exynos                  53                53                53       53
# MediaTek               144               144               144      144
# ...

# %%
df2=df2.reset_index()

# %%
df2.plot(x='processor',y='brand',kind='bar')
# Out:
# <AxesSubplot:xlabel='processor'>

# %%
import seaborn as sns

# %%
pd.crosstab(df['base_color'],df['brand'])
# Out:
# brand       Apple  Poco  Realme  Samsung  Xiaomi
# base_color
# Black          12    17      26       38      19
# Blue            8    18      43       33      15
# Bronze          0     2       0        3       0
# Gold            1     0       0        2       8
# Gray            0     3       9        7       1
# Green           6     2       5       10       1
# Others          4     3       9        9       3
# Purple          4     0       1        0       0
# Red             7     3       2        4       5
# Silver          0     3      24        3       2
# White          11     0      16       10       7
# Yellow          3     5       3        0       0

# %% [markdown]
# # DATA VISUALISATION

# %%
hf=df.brand.value_counts()

# %%
hf.index
# Out:
# Index(['Realme', 'Samsung', 'Xiaomi', 'Apple', 'Poco'], dtype='object')

# %% [markdown]
# ### BAR PLOT

# %%
plt.bar(hf.index,hf,color = ['r','g','b','orange','black'])
plt.xlabel('Brands')
plt.ylabel('Count')
plt.title('mobile brands counts')
plt.show()

# %% [markdown]
# ### inference: realme has the most no. of sale and apple, poco is least

# %%
sns.countplot(x='brand',data=df)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='count'>

# %%
sns.countplot(x='processor',data=df)
# Out:
# <AxesSubplot:xlabel='processor', ylabel='count'>

# %%
sns.countplot(x='brand',data=df, hue='RAM',orient='y')
# Out:
# <AxesSubplot:xlabel='brand', ylabel='count'>

# %%
sns.countplot(x='processor',data=df, hue='ROM',orient='y')
# Out:
# <AxesSubplot:xlabel='processor', ylabel='count'>

# %%
bar = sns.countplot(x='brand',data=df,hue='RAM',orient='h',palette = 'turbo_r',order = ['Poco','Xiaomi','Samsung','Realme','Apple'])
for containers in bar.containers:
    bar.bar_label(containers)

# %% [markdown]
# ## HISTOGRAM

# %% [markdown]
# #### USED TO SUMMARIZE BOTH DISCRETE AND CONTINIOUS

# %%
#bins is used to alter the scatter of the data
plt.hist(x='battery_capacity',bins=10,data=df,orientation='horizontal',color='orange',density=True)
# Out:
# (array([2.23613596e-05, 1.56529517e-04, 1.34168157e-04, 1.34168157e-05,
#         4.47227191e-04, 2.32558140e-04, 6.48479428e-04, 0.00000000e+00,
#         2.41502683e-04, 2.68336315e-05]),
#  array([1800., 2320., 2840., 3360., 3880., 4400., 4920., 5440., 5960.,
#         6480., 7000.]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df, x='battery_capacity',bins=7,kde=True)
# kde: kernel density estimate
# Out:
# <AxesSubplot:xlabel='battery_capacity', ylabel='Count'>

# %%
sns.histplot(df, x='battery_capacity',bins=7,kde=False)
# Out:
# <AxesSubplot:xlabel='battery_capacity', ylabel='Count'>

# %%
sns.kdeplot(data = df, x='battery_capacity')
# Out:
# <AxesSubplot:xlabel='battery_capacity', ylabel='Density'>

# %% [markdown]
# ## PIE PLOT

# %% [markdown]
# #### shows categorial values in numerical values

# %%
label=df['brand'].value_counts().index
count=df['brand'].value_counts().values

# %%
label
# Out:
# Index(['Realme', 'Samsung', 'Xiaomi', 'Apple', 'Poco'], dtype='object')

# %%
count
# Out:
# array([138, 119,  61,  56,  56], dtype=int64)

# %%
plt.pie(count,labels=label,shadow = True,colors=['lightgreen','lightblue','maroon','beige','orange'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1d244139580>,
# ...
#  [Text(0.5866927109901305, 0.9304792651483703, 'Realme'),
#   Text(-1.0642320849372113, 0.27822665111415285, 'Samsung'),
#   Text(-0.5383595521792354, -0.9592543940881237, 'Xiaomi'),
#   Text(0.3703424669282642, -1.035783016461212, 'Apple'),
#   Text(1.009210687325674, -0.43760003266412234, 'Poco')])

# %%
exploded=[0.05,0,0.1,0.3,0.2]
plt.pie(count,labels=label,shadow = True,colors=['lightgreen','lightblue','maroon','beige','orange'],explode=exploded)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d244ee5430>,
# ...
#  [Text(0.6133605614896819, 0.972773777200569, 'Realme'),
#   Text(-1.0642320849372113, 0.27822665111415285, 'Samsung'),
#   Text(-0.587301329650075, -1.046459339005226, 'Xiaomi'),
#   Text(0.4713449579086999, -1.3182692936779064, 'Apple'),
#   Text(1.1927035395667058, -0.51716367496669, 'Poco')])

# %%
plt.pie(count,labels=label,shadow = False,colors=['lightgreen','lightblue','yellow','beige','orange'],autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d23ff52a30>,
# ...
#  [Text(0.5866927109901305, 0.9304792651483703, 'Realme'),
#   Text(-1.0642320849372113, 0.27822665111415285, 'Samsung'),
#   Text(-0.5383595521792354, -0.9592543940881237, 'Xiaomi'),
#   Text(0.3703424669282642, -1.035783016461212, 'Apple'),
#   Text(1.009210687325674, -0.43760003266412234, 'Poco')],
#  [Text(0.32001420599461666, 0.5075341446263837, '32.09%'),
#   Text(-0.5804902281475697, 0.1517599915168106, '27.67%'),
#   Text(-0.29365066482503743, -0.523229669502613, '14.19%'),
#   Text(0.20200498196087138, -0.5649725544333883, '13.02%'),
#   Text(0.5504785567230949, -0.23869092690770308, '13.02%')])

# %% [markdown]
# ## DOUGHNUT CHART

# %% [markdown]
# ### Modified piechart

# %%
my_circle = plt.Circle((0,0),0.35,color='white')

plt.pie(count, labels=label,autopct='%0.2f%%',colors=['red','green','blue','yellow','beige'])

p=plt.gcf()
p.gca().add_artist(my_circle)
plt.legend(label,loc='upper right',title='BRANDS')
plt.show()

# %% [markdown]
# ## SCATTER PLOT

# %% [markdown]
# ### Both values should be numerical data

# %%
plt.scatter(x='RAM',y='ROM',data=df)
plt.xlabel('RAM')
plt.ylabel('ROM')
plt.title('RAM VS ROM')
# Out:
# Text(0.5, 1.0, 'RAM VS ROM')

# %% [markdown]
# ### Shows relationship between RAM and ROM

# %% [markdown]
# ### In this case positive linear relation between RAM and ROM, ie when RAM increases ROM increases

# %%
sns.scatterplot(x='RAM',y='ROM', data=df,hue='brand',style='brand')
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='ROM'>

# %% [markdown]
# # BOX PLOT

# %% [markdown]
# #### * Displays five number summary of a set of data (min,lower-quartile,median,higher-quartile,max)
# #### * used to represent numerical data
# #### * used when data has outliers
# #### * also called "box & whisker diagram"

# %%
plt.boxplot(df['display_size'])
plt.xlabel=('display')
plt.ylabel=('screen_size')
plt.title('box plot for display')
# Out:
# Text(0.5, 1.0, 'box plot for display')

# %%
sns.boxplot(y='display_size',data=df)
# Out:
# <AxesSubplot:ylabel='display_size'>

# %%
sns.boxplot(x='RAM',y='processor',data=df,hue='brand')
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='processor'>
